# %%
print('hello world')
# Out:
# hello world

# %%
from langchain_community.document_loaders import TextLoader

# %%
txt_laoder = TextLoader(
    file_path = r"/Users/pradipwasre/Desktop/GenAI/Langchain/Doc_loader/match_summary.txt",
    encoding = "utf-8"
)

# %%
txt_docs = txt_laoder.load()

# %%
len(txt_docs)
# Out:
# 1

# %%
print(txt_docs[0])
# Out:
# page_content='IPL 2026 - Match 48 (Night Game)
# Venue: Delhi, May 05, 2026
# Indian Premier League
#
# === RESULT ===
# Chennai Super Kings beat Delhi Capitals by 8 wickets (with 15 balls remaining)
# Delhi Capitals scored 155/7 in 20 overs.
# Chennai Super Kings chased it down in 17.3 overs, finishing at 159/2.
#
# === PLAYER OF THE MATCH ===
# Sanju Samson (CSK) - 87* off 52 balls (7 fours, 6 sixes, SR: 167.30)
# Cricinfo MVP Points: 105.96
#
# === DELHI CAPITALS BATTING ===
# Pathum Nissanka: 19 runs off 15 balls (3 fours, 1 six) - c Brevis b Mukesh Choudhary
# KL Rahul: 12 runs off 13 balls (2 fours) - c Gaikwad b Hosein
# Nitish Rana: 15 runs off 13 balls (2 fours) - c Kartik Sharma b Noor Ahmad
# Karun Nair: 13 runs off 13 balls (2 fours) - c Gurjapneet Singh b Noor Ahmad
# Axar Patel (c): 2 runs off 6 balls - c Hosein b Gurjapneet Singh
# Tristan Stubbs: 38 runs off 31 balls (1 four, 2 sixes) - c Mukesh Choudhary b Overton
# Sameer Rizvi: 40* off 24 balls (4 sixes, SR: 166.66) - not out
# Ashutosh Sharma: 14 runs off 5 balls (2 sixes, SR: 280.00) - run out
# Mitchell Starc: 0* not out
# Extras: 2 wides
# Total: 155/7 in 20 overs (Run Rate: 7.75)
#
# Fall of Wickets (DC):
# 1st wicket: 29 runs (Nissanka, over 3.6)
# 2nd wicket: 36 runs (KL Rahul, over 5.1)
# 3rd wicket: 52 runs (Karun Nair, over 7.6)
# 4th wicket: 61 runs (Nitish Rana, over 9.3)
# 5th wicket: 69 runs (Axar Patel, over 10.6)
# 6th wicket: 134 runs (Tristan Stubbs, over 18.5)
# 7th wicket: 149 runs (Ashutosh Sharma, over 19.5)
#
# === DELHI CAPITALS BOWLING ===
# Mitchell Starc: 4 overs, 0 maiden, 30 runs, 0 wickets, Econ: 7.50
# Axar Patel: 4 overs, 0 maiden, 25 runs, 1 wicket, Econ: 6.25
# Lungi Ngidi: 4 overs, 0 maiden, 30 runs, 1 wicket, Econ: 7.50
# Kuldeep Yadav: 3 overs, 0 maiden, 34 runs, 0 wickets, Econ: 11.33
# T Natarajan: 2.3 overs, 0 maiden, 39 runs, 0 wickets, Econ: 15.60
#
# === CHENNAI SUPER KINGS BATTING ===
# Sanju Samson: 87* off 52 balls (7 fours, 6 sixes, SR: 167.30) - not out
# Ruturaj Gaikwad (c): 6 runs off 13 balls (1 four) - c Sameer Rizvi b Ngidi
# Urvil Patel: 17 runs off 9 balls (2 sixes, SR: 188.88) - st KL Rahul b Axar Patel
# Kartik Sharma: 41* off 31 balls (4 fours, 2 sixes, SR: 132.25) - not out
# Extras: 1 leg bye, 7 wides
# Total: 159/2 in 17.3 overs (Run Rate: 9.08)
#
# Fall of Wickets (CSK):
# 1st wicket: 24 runs (Ruturaj Gaikwad, over 3.5)
# 2nd wicket: 45 runs (Urvil Patel, over 6.3)
#
# === CSK BOWLING (vs DC) ===
# Akeal Hosein: 4 overs, 0 maiden, 19 runs, 1 wicket, Econ: 4.75
# Mukesh Choudhary: 4 overs, 0 maiden, 31 runs, 1 wicket, Econ: 7.75
# Anshul Kamboj: 4 overs, 0 maiden, 49 runs, 0 wickets, Econ: 12.25
# Noor Ahmad: 3 overs, 0 maiden, 22 runs, 2 wickets, Econ: 7.33
# Gurjapneet Singh: 4 overs, 0 maiden, 29 runs, 1 wicket, Econ: 7.25
# Jamie Overton: 1 over, 0 maiden, 5 runs, 1 wicket, Econ: 5.00
#
# === POST MATCH QUOTES ===
#
# Ruturaj Gaikwad (CSK Captain):
# "We were always positive, we were always closer than we were last year, we had covered all bases. Sanju coming in... we just needed a couple of wins, after the third game we got that and it started coming together. Obviously Sanju is the backbone now. The bowling wins you tournaments, we have Akeal, Overton, Kamboj is also there, smart bowler, he had an off day today but he's been impressive. Kartik Sharma's skillset was already there, he just needed a couple of games to start with, he didn't get the time in previous games, now he got the time, he's not a wild slogger, he can rotate strike and hit the pockets."
#
# Sanju Samson (Player of the Match):
# "I have been working a bit on my initial movement and it has been coming off. I've been doing it for the last few years and it's tactical as well depending on the bowlers. To be very honest I am always calm but you are seeing me more in the middle now so you feel I am calm. Looking at what we were chasing, how the wicket was behaving, even if we were 35 for no loss in the powerplay, we could capitalise in the middle overs. I had to be a bit too selfish to get a hundred so I thought lets win the game. Finishing not out, winning the game gives you more satisfaction."
#
# Axar Patel (DC Captain):
# "DC were 10-15 runs short. The wicket got a little better to bat on later in the game, especially for batters who were set. It wasn't easy for new batters to get set, but with set batters they were able to take the game away."
#
# === KEY PARTNERSHIPS (CSK Chase) ===
# 3rd wicket partnership (Samson + Kartik Sharma): 114 runs off 66 balls
# This partnership won the game for CSK.
# Samson reached his half-century off 32 balls (3 fours, 4 sixes).
#
# === MATCH NOTES ===
# - CSK did not use their Impact Player substitute.
# - Delhi Capitals used Sameer Rizvi as Impact Player sub for Karun Nair (over 10.6).
# - Natarajan was expensive in death overs (Econ: 15.60 in 2.3 overs).
# - Anshul Kamboj had an off day (49 runs in 4 overs, 0 wickets).
# - CSK move to 6th place but are now only 2 points behind teams ranked 2nd through 5th.
# - Next match: SRH vs PBKS.
# ' metadata={'source': '/Users/pradipwasre/Desktop/GenAI/Langchain/Doc_loader/match_summary.txt'}

# %%
print(txt_docs[0].page_content[:100])
# Out:
# IPL 2026 - Match 48 (Night Game)
# Venue: Delhi, May 05, 2026
# Indian Premier League
#
# === RESULT ===
# Ch

# %%
a= [100]

# %%
len(a)
# Out:
# 1

# %%
a[0]
# Out:
# 100

# %%
from langchain_community.document_loaders.csv_loader import CSVLoader

# %%
batting_loader = CSVLoader(
    file_path = r"/Users/pradipwasre/Desktop/GenAI/Langchain/Doc_loader/batting_scorecard.csv",
    encoding = "utf-8"
)

# %%
batting_docs = batting_loader.load()

# %%
len(batting_docs)
# Out:
# 13

# %%
pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.9-cp311-cp311-macosx_11_0_arm64.whl.metadata (52 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.62.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (117 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.1 kB)
# Requirement already satisfied: numpy>=1.23 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib) (2.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/pradipwasre/Library/Python/3.11/lib/python/site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=8 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib) (12.2.0)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/pradipwasre/Library/Python/3.11/lib/python/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/pradipwasre/Library/Python/3.11/lib/python/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.9-cp311-cp311-macosx_11_0_arm64.whl (8.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 5.3 MB/s eta 0:00:00a 0:00:01m
# Downloading contourpy-1.3.3-cp311-cp311-macosx_11_0_arm64.whl (270 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.62.1-cp311-cp311-macosx_10_9_universal2.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 2.7 MB/s eta 0:00:00a 0:00:01
# Downloading kiwisolver-1.5.0-cp311-cp311-macosx_11_0_arm64.whl (63 kB)
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, kiwisolver, fonttools, cycler, contourpy, matplotlib
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [matplotlib]6 [matplotlib]
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.62.1 kiwisolver-1.5.0 matplotlib-3.10.9 pyparsing-3.3.2
#
# [notice] A new release of pip is available: 25.1.1 -> 26.1.1
# [notice] To update, run: /opt/homebrew/opt/python@3.11/bin/python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
print(batting_docs[0])
# Out:
# page_content='team: Delhi Capitals
# player: Pathum Nissanka
# role: batter
# runs: 19
# balls: 15
# minutes: 18
# fours: 3
# sixes: 1
# strike_rate: 126.66
# dismissal: caught
# bowler: Mukesh Choudhary
# fielder: Brevis' metadata={'source': '/Users/pradipwasre/Desktop/GenAI/Langchain/Doc_loader/batting_scorecard.csv', 'row': 0}

# %%
print(batting_docs[0].page_content)
# Out:
# team: Delhi Capitals
# player: Pathum Nissanka
# role: batter
# runs: 19
# balls: 15
# minutes: 18
# fours: 3
# sixes: 1
# strike_rate: 126.66
# dismissal: caught
# bowler: Mukesh Choudhary
# fielder: Brevis

# %%
print(batting_docs[0].metadata)
# Out:
# {'source': '/Users/pradipwasre/Desktop/GenAI/Langchain/Doc_loader/batting_scorecard.csv', 'row': 0}

# %%
# Bowling:
bowling_loader = CSVLoader(
    file_path = r"/Users/pradipwasre/Desktop/GenAI/Langchain/Doc_loader/bowling_figures.csv",
    encoding = "utf-8"
)
