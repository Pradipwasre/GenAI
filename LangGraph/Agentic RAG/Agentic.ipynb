# %% [markdown]
# # Conversational RAG with Gradio – Code Flow & Use Cases
#
# ## 1. What is RAG?
# **Retrieval-Augmented Generation (RAG)** combines:
# - **Retriever** → fetches relevant documents from a knowledge base.
# - **Generator (LLM)** → produces answers grounded in those documents.
#
# This ensures responses are **accurate, contextual, and traceable**.
#
# ---
#
# ## 2. Code Flow Overview
#
# ### Offline Setup (Data Preparation)
# 1. **Web Loader** → Fetches webpage content (Cricbuzz RCB results).
# 2. **Text Splitter** → Breaks content into chunks.
# 3. **Embeddings** → Converts chunks into vectors (HuggingFace model).
# 4. **Vector Store (FAISS)** → Stores embeddings for fast retrieval.
#
# ### Online Query Flow (User Interaction)
# 1. **User Prompt** → Typed into Gradio Chat.
# 2. **Retriever Node** → Finds relevant chunks from FAISS.
# 3. **Responder Node** → Sends context + question to Groq LLM.
# 4. **Groq LLM** → Generates grounded answer.
# 5. **Gradio ChatInterface** → Streams answer back like ChatGPT.
#
# ---
#
# ## 3. Diagram : Code Flow

# %%
![AI Agent Query Processing Flow](./images/AI_Agent_Query_Processing.png)
# Out:
# zsh:1: bad pattern: [AI

# %% [markdown]
# # Agentic RAG

# %%
# -----------------------------
# 0. Setup & Imports
# -----------------------------
import os
from typing import List
from pydantic import BaseModel

from dotenv import load_dotenv
from langchain_community.vectorstores import FAISS
from langchain_community.document_loaders import WebBaseLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_groq import ChatGroq   # Groq LLM integration
from langchain_huggingface import HuggingFaceEmbeddings   # HuggingFace embeddings
from langchain_core.documents import Document
from langgraph.graph import StateGraph, END

# %%
# Load environment variables
load_dotenv()
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# Initialize Groq LLM
llm = ChatGroq(
    model="llama-3.1-8b-instant",
    api_key=os.environ["GROQ_API_KEY"]
)

# %%
# -----------------------------
# 1. Document Loading
# -----------------------------
# Use Cricbuzz RCB results page (static HTML, works with WebBaseLoader)
urls = ["https://www.cricbuzz.com/cricket-team/royal-challengers-bangalore/59/results"]

loader = WebBaseLoader(urls)
docs = loader.load()

print(f"Loaded {len(docs)} documents from Cricbuzz")
# Out:
# Loaded 1 documents from Cricbuzz

# %%
# -----------------------------
# 2. Text Splitting & Vector Store
# -----------------------------
splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=50
)
split_docs = splitter.split_documents(docs)

embedding = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
vectorstore = FAISS.from_documents(split_docs, embedding)
retriever = vectorstore.as_retriever()

print("Retriever Test:", retriever.invoke("RCB recent match score"))
# Out:
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 5505.11it/s]
# 🔎 Retriever Test: [Document(id='e4f5faa6-ed5c-46cb-aafa-1b205b6ba06b', metadata={'source': 'https://www.cricbuzz.com/cricket-team/royal-challengers-bangalore/59/results', 'title': 'Royal Challengers Bengaluru Cricket Team matches, scorecards, news and statistics | Cricbuzz.com', 'description': 'Royal Challengers Bengaluru Cricket Team Latest News & Info, Photo Gallery, Stats, Squad, Ranking, Venues & Cricket Score of all the matches on Cricbuzz.com', 'language': 'en'}, page_content="Royal Challengers Bengaluru Cricket Team matches, scorecards, news and statistics | Cricbuzz.comMenuLive ScoresScheduleArchivesNewsSeriesTeamsVideosRankingsMoreMATCHESRR vs SRH - RR wonNZ vs IRE - StumpsRCB vs GT - RCB wonDERBY vs LEIC - DERBY wonENGW vs INDW - PreviewALLAllLive NowTodayINTERNATIONALICC Men's T20 World Cup Sub Regional Africa Qualifier Group A 2026Botswana vs Ivory Coast 13th MatchSierra Leone vs Rwanda 14th MatchCameroon vs Kenya 15th MatchCameroon vs Mali 16th MatchIvory Coast"), Document(id='85de36e5-8272-43fb-b458-5ff70af90627', metadata={'source': 'https://www.cricbuzz.com/cricket-team/royal-challengers-bangalore/59/results', 'title': 'Royal Challengers Bengaluru Cricket Team matches, scorecards, news and statistics | Cricbuzz.com', 'description': 'Royal Challengers Bengaluru Cricket Team Latest News & Info, Photo Gallery, Stats, Squad, Ranking, Venues & Cricket Score of all the matches on Cricbuzz.com', 'language': 'en'}, page_content="15th MatchCameroon vs Mali 16th MatchIvory Coast vs Sierra Leone 17th MatchNew Zealand tour of Ireland, 2026New Zealand vs Ireland Only TestLEAGUEIPL 2026Rajasthan Royals vs Sunrisers Hyderabad EliminatorT20 Blast 2026Derbyshire vs Leicestershire 19th MatchWOMENIndia Women tour of EnglandEngland Women vs India Women 1st T20IAsian Games Women's T20I Qualifier 2026Malaysia Women vs Hong Kong, China Women  5th Match, Group AIndonesia Women vs Nepal Women  6th Match, Group BWomen's Tri-Series in"), Document(id='0282e2b2-7f1a-426a-bbc8-125f822bc78a', metadata={'source': 'https://www.cricbuzz.com/cricket-team/royal-challengers-bangalore/59/results', 'title': 'Royal Challengers Bengaluru Cricket Team matches, scorecards, news and statistics | Cricbuzz.com', 'description': 'Royal Challengers Bengaluru Cricket Team Latest News & Info, Photo Gallery, Stats, Squad, Ranking, Venues & Cricket Score of all the matches on Cricbuzz.com', 'language': 'en'}, page_content="Women  6th Match, Group BWomen's Tri-Series in Ireland, 2026Ireland Women vs Pakistan Women 1st MatchOman Women and Bahrain Women tour of MalaysiaOman Women vs Bahrain Women 1st T20IWomens T20 Blast 2026Somerset Women vs Yorkshire Women 12th MatchWarwickshire Women vs The Blaze Women 10th MatchDurham Women vs Surrey Women 11th MatchScotland Women's T20I Tri-Series, 2026Scotland Women vs Netherlands Women 1st Matchroyal challengers bengaluruCricket"), Document(id='43a24890-a33b-47cf-970a-88d7d0cd55b7', metadata={'source': 'https://www.cricbuzz.com/cricket-team/royal-challengers-bangalore/59/results', 'title': 'Royal Challengers Bengaluru Cricket Team matches, scorecards, news and statistics | Cricbuzz.com', 'description': 'Royal Challengers Bengaluru Cricket Team Latest News & Info, Photo Gallery, Stats, Squad, Ranking, Venues & Cricket Score of all the matches on Cricbuzz.com', 'language': 'en'}, page_content="Women 1st Matchroyal challengers bengaluruCricket TeamHomeScheduleResultsNewsVideosPhotosStatsPlayersVenuesAllLATEST NEWSIPL Pulse: Age no bar\xa0The lightness of being Vaibhav Sooryavanshi\xa0He doesn't give a damn about the bowler - Jurel on Sooryavanshi's approach\xa0Blundell, Ravindra revive New Zealand after early wobble on Day 1\xa0Vaibhav Sooryavanshi becomes IPL's new six-hitting king\xa0Sooryavanshi special headlines Rajasthan Royals' Eliminator win\xa0More NewsMove to TopAPPSAndroidiOSFOLLOW US")]

# %%
# -----------------------------
# 3. Define RAG State
# -----------------------------
class RAGState(BaseModel):
    question: str
    retrieved_docs: List[Document] = []
    answer: str = ""

# %%
# -----------------------------
# 4. LangGraph Nodes
# -----------------------------
def retrieve_docs(state: RAGState) -> RAGState:
    docs = retriever.invoke(state.question)
    return RAGState(question=state.question, retrieved_docs=docs)

def generate_answer(state: RAGState) -> RAGState:
    context = "\n\n".join([doc.page_content for doc in state.retrieved_docs])
    prompt = f"Answer the question based on the context.\n\nContext:\n{context}\n\nQuestion: {state.question}"
    response = llm.invoke(prompt)
    return RAGState(
        question=state.question,
        retrieved_docs=state.retrieved_docs,
        answer=response.content
    )

# %%
# -----------------------------
# 5. Build LangGraph
# -----------------------------
builder = StateGraph(RAGState)
builder.add_node("retriever", retrieve_docs)
builder.add_node("responder", generate_answer)

builder.set_entry_point("retriever")
builder.add_edge("retriever", "responder")
builder.add_edge("responder", END)

graph = builder.compile()

# %%
# -----------------------------
# 6. Run the Agentic RAG
# -----------------------------
if __name__ == "__main__":
    user_question = "RCB status"
    initial_state = RAGState(question=user_question)
    final_state = graph.invoke(initial_state)

    print("\n Final Answer:\n", final_state['answer'])
# Out:
#  Final Answer:
#  RCB (Royal Challengers Bengaluru) status is - RCB won. This is mentioned in the matches section of the webpage where it is stated that "RCB vs GT - RCB won".

# %%
def rag_pipeline(user_question: str):
    initial_state = RAGState(question=user_question)
    final_state = graph.invoke(initial_state)
    return final_state['answer']

demo = gr.Interface(
    fn=rag_pipeline,
    inputs=gr.Textbox(lines=2, placeholder="Ask about RCB recent matches..."),
    outputs="text",
    title="RCB Match Results RAG",
    description="Ask questions like 'recent match score of RCB' or 'last 5 matches of RCB'."
)

if __name__ == "__main__":
    demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import gradio as gr

# %% [markdown]
# # Agentic RAG with memory

# %%
# -----------------------------
# 0. Setup & Imports
# -----------------------------
import os
from typing import List
from pydantic import BaseModel

import gradio as gr
from dotenv import load_dotenv
from langchain_community.vectorstores import FAISS
from langchain_community.document_loaders import WebBaseLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_groq import ChatGroq
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_core.documents import Document
from langgraph.graph import StateGraph, END

# Load environment variables
load_dotenv()
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# Initialize Groq LLM with streaming enabled
llm = ChatGroq(
    model="llama-3.1-8b-instant",
    api_key=os.environ["GROQ_API_KEY"],
    streaming=True   # enables token-by-token streaming
)

# -----------------------------
# 1. Document Loading
# -----------------------------
urls = ["https://www.cricbuzz.com/cricket-team/royal-challengers-bangalore/59/results"]
loader = WebBaseLoader(urls)
docs = loader.load()

# -----------------------------
# 2. Text Splitting & Vector Store
# -----------------------------
splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=50
)
split_docs = splitter.split_documents(docs)

embedding = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
vectorstore = FAISS.from_documents(split_docs, embedding)
retriever = vectorstore.as_retriever()

# -----------------------------
# 3. Define RAG State
# -----------------------------
class RAGState(BaseModel):
    question: str
    retrieved_docs: List[Document] = []
    answer: str = ""

# -----------------------------
# 4. LangGraph Nodes
# -----------------------------
def retrieve_docs(state: RAGState) -> RAGState:
    docs = retriever.invoke(state.question)
    return RAGState(question=state.question, retrieved_docs=docs)

def generate_answer(state: RAGState) -> RAGState:
    context = "\n\n".join([doc.page_content for doc in state.retrieved_docs])
    prompt = f"Answer the question based on the context.\n\nContext:\n{context}\n\nQuestion: {state.question}"
    response = llm.invoke(prompt)
    return RAGState(
        question=state.question,
        retrieved_docs=state.retrieved_docs,
        answer=response.content
    )

# -----------------------------
# 5. Build LangGraph
# -----------------------------
builder = StateGraph(RAGState)
builder.add_node("retriever", retrieve_docs)
builder.add_node("responder", generate_answer)

builder.set_entry_point("retriever")
builder.add_edge("retriever", "responder")
builder.add_edge("responder", END)

graph = builder.compile()
# Out:
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 6903.38it/s]

# %%
# -----------------------------
# 6. Gradio Chat Interface
# -----------------------------
def rag_chat(user_message, history):
    """Chat-style RAG pipeline with context following"""
    initial_state = RAGState(question=user_message)
    final_state = graph.invoke(initial_state)
    return final_state['answer']

demo = gr.ChatInterface(
    fn=rag_chat,
    title=" RCB Match Results Chat RAG",
    description="Ask about RCB matches, scores, and results. Conversation flows like ChatGPT with context."
)

if __name__ == "__main__":
    demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7863
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7863/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
